# %%
from bassena_stats_functions import *

# Read the original csv file with the data ("name_of_file.csv")
bassenaoriginal = read_original_csv("bassena3.csv")

print("------------------------------------------------")

print("\n")
print("Brutto Umsatzt por Wochentag")
print("\n")
print(f"Total day mean value: {calculate_total_day_mean(bassenaoriginal)[0]}")
print(f"Total day median value: {calculate_total_day_mean(bassenaoriginal)[1]}")
print("\n")

print("------------------------------------------------")

calculate_weekday("Monday", bassenaoriginal)
calculate_weekday("Tuesday", bassenaoriginal)
calculate_weekday("Wednesday", bassenaoriginal)
calculate_weekday("Thursday", bassenaoriginal)
calculate_weekday("Friday", bassenaoriginal)
calculate_weekday("Saturday", bassenaoriginal)
calculate_weekday("Sunday", bassenaoriginal)
# Out:
# ------------------------------------------------
#
#
# Brutto Umsatzt por Wochentag
#
#
# Total day mean value: 379.97
# Total day median value: 359.19
#
#
# ------------------------------------------------
#
#
# -----------------------------------------------------
#
#
# Brutto Umsatz at Monday
# Durchschnitt Value: 432.1 €
# Median Value: 444.25 €
#
#
# Detail:
#
#
# 194.18 € - 04.01.21
# 222.43 € - 11.01.21
# 199.2 € - 18.01.21
# 331.34 € - 25.01.21
# 476.39 € - 01.02.21
# 322.24 € - 08.02.21
# 354.63 € - 15.02.21
# 314.75 € - 22.02.21
# 341.52 € - 01.03.21
# 275.89 € - 08.03.21
# 364.86 € - 15.03.21
# 250.77 € - 22.03.21
# 383.42 € - 29.03.21
# 403.7 € - 12.04.21
# 390.43 € - 19.04.21
# 347.08 € - 26.04.21
# 390.57 € - 03.05.21
# 444.25 € - 10.05.21
# 275.07 € - 17.05.21
# 448.42 € - 31.05.21
# 528.35 € - 07.06.21
# 486.65 € - 14.06.21
# 517.56 € - 21.06.21
# 582.4 € - 28.06.21
# 703.39 € - 05.07.21
# 465.28 € - 12.07.21
# 474.75 € - 19.07.21
# 553.15 € - 26.07.21
# ...
