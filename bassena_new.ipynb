# %%
from flour_stats import *

# Read the original csv file with the data ("name_of_file.csv")
bassena = flour_stats("bassena3.csv")

print("------------------------------------------------")

print("\n")
print("Brutto Umsatzt pro Wochentag")
print("\n")
print(f"Total day mean value: {bassena.totaldaymean}")
print(f"Total day median value: {bassena.totaldaymedian}")
print("\n")

print("------------------------------------------------")

bassena.calculate_weekday("Monday")
bassena.calculate_weekday("Tuesday")
bassena.calculate_weekday("Wednesday")
bassena.calculate_weekday("Thursday")
bassena.calculate_weekday("Friday")
bassena.calculate_weekday("Saturday")
bassena.calculate_weekday("Sunday")
# Out:
# ------------------------------------------------
#
#
# Brutto Umsatzt pro Wochentag
#
#
# Total day mean value: 379.97
# Total day median value: 359.19
#
#
# ------------------------------------------------
#
#
# -----------------------------------------------------
# -----------------------------------------------------
#
#
# Brutto Umsatz at Monday
# Durchschnitt Value: 432.1 €
# Median Value: 444.25 €
#
#
# Money and Rain comparison
# Money and customers comparison
# Detail:
#
#
#          Day Brutto Umsatz  Rain Temperature Average Korb Anzahl Korb
# 0   04.01.21      194.18 €   0.0       3.6 °       4.98 €          39
# 1   11.01.21      222.43 €   0.0      -0.4 °       6.08 €          37
# 2   18.01.21       199.2 €   2.2      -1.1 °       5.53 €          36
# 3   25.01.21      331.34 €   0.0       3.4 °       6.14 €          54
# 4   01.02.21      476.39 €   0.0       0.7 °       6.94 €          72
# 5   08.02.21      322.24 €   2.7       1.2 °       5.75 €          56
# ...
